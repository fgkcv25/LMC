# %%
with open('C:\\Users\\05873472955\\Desktop\\DTB_2014_Municipio.csv','r') as arquivo:
    dados = arquivo.read()
print(dados)
# Out:
# UF,Nome_UF,Mesorregi?o Geográfica,Nome_Mesorregi?o,Microrregi?o Geográfica,Nome_Microrregi?o,Município,Cod Municipio Completo,Nome_Município
# 11,Rondônia,02,Leste Rondoniense,006,Cacoal,00015,1100015,'Alta Floresta D''Oeste'
# 11,Rondônia,02,Leste Rondoniense,003,Ariquemes,00023,1100023,Ariquemes
# 11,Rondônia,02,Leste Rondoniense,008,Colorado do Oeste,00031,1100031,Cabixi
# 11,Rondônia,02,Leste Rondoniense,006,Cacoal,00049,1100049,Cacoal
# 11,Rondônia,02,Leste Rondoniense,008,Colorado do Oeste,00056,1100056,Cerejeiras
# 11,Rondônia,02,Leste Rondoniense,008,Colorado do Oeste,00064,1100064,Colorado do Oeste
# 11,Rondônia,02,Leste Rondoniense,008,Colorado do Oeste,00072,1100072,Corumbiara
# 11,Rondônia,01,Madeira-Guaporé,002,Guajará-Mirim,00080,1100080,Costa Marques
# 11,Rondônia,02,Leste Rondoniense,006,Cacoal,00098,1100098,'Espig?o D''Oeste'
# 11,Rondônia,01,Madeira-Guaporé,002,Guajará-Mirim,00106,1100106,Guajará-Mirim
# ...

# %%
import pandas as pd

# %%
with open('C:\\Users\\05873472955\\Desktop\\DTB_2014_Municipio.csv','r') as arquivo:
    dados = pd.read_csv(arquivo) 
print(dados)
# Out:
#       UF           Nome_UF  Mesorregi?o Geográfica   Nome_Mesorregi?o  \
# 0     11          Rondônia                       2  Leste Rondoniense
# 1     11          Rondônia                       2  Leste Rondoniense
# 2     11          Rondônia                       2  Leste Rondoniense
# 3     11          Rondônia                       2  Leste Rondoniense
# 4     11          Rondônia                       2  Leste Rondoniense
# 5     11          Rondônia                       2  Leste Rondoniense
# 6     11          Rondônia                       2  Leste Rondoniense
# 7     11          Rondônia                       1    Madeira-Guaporé
# 8     11          Rondônia                       2  Leste Rondoniense
# 9     11          Rondônia                       1    Madeira-Guaporé
# 10    11          Rondônia                       2  Leste Rondoniense
# 11    11          Rondônia                       2  Leste Rondoniense
# ...

# %%
dados[['Nome_UF','Nome_Município']]
# Out:
#                Nome_UF               Nome_Município
# 0             Rondônia     'Alta Floresta D''Oeste'
# 1             Rondônia                    Ariquemes
# 2             Rondônia                       Cabixi
# 3             Rondônia                       Cacoal
# 4             Rondônia                   Cerejeiras
# 5             Rondônia            Colorado do Oeste
# 6             Rondônia                   Corumbiara
# 7             Rondônia                Costa Marques
# 8             Rondônia           'Espig?o D''Oeste'
# 9             Rondônia                Guajará-Mirim
# 10            Rondônia                         Jaru
# 11            Rondônia                    Ji-Paraná
# 12            Rondônia        'Machadinho D''Oeste'
# 13            Rondônia  'Nova Brasilândia D''Oeste'
# 14            Rondônia          Ouro Preto do Oeste
# 15            Rondônia                Pimenta Bueno
# 16            Rondônia                  Porto Velho
# ...

# %%
len(dados.loc[dados['Nome_UF'] == 'Goiás'])
# Out:
# 246
